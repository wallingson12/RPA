# %% [markdown]
# # PDF PARA EXCEL

# %%
import pdfminer.high_level as pdf
import pandas as pd
import xml.etree.ElementTree as ET

def Extrair_Modelo_SP(pdf_file, output_file):
    # Extrai o texto do PDF
    text = pdf.extract_text(pdf_file)

    # Cria um dicionário para armazenar as informações extraídas
    data = {
        'Nome do Tomador': [],
        'CNPJ do Tomador': [],
        'Nome do Prestador': [],
        'CNPJ do Prestador': [],
        'Número da Nota': [],
        'Data de Emissão': [],
        'Valor Total': [],
        'Código de Serviço': [],
        'Alíquota ISS': [],
        'Valor ISS': [],
        #'Valor IRRF': [],
        #'Valor CSLL': [],
        #'Valor PIS': [],
        #'Valor COFINS': [],
        #'Valor INSS': [],
        #'Valor ISS retido': [],
    }

    # Extrai as informações do texto
    lines = text.split('\n')
    for i in range(len(lines)):
        
        if lines[i].startswith('TOMADOR DE SERVIÇOS'):
            data['Nome do Tomador'].append(' '.join(lines[i+2].split()[2:5]))
            data['CNPJ do Tomador'].append(' '.join(lines[i+3].split()[1]))
            
        elif lines[i].startswith('PRESTADOR DE SERVIÇOS'):
            data['Nome do Prestador'].append(' '.join(lines[19].split()[1]))
            data['CNPJ do Prestador'].append(' '.join(lines[20].split()[1:5]))

        elif lines[i].startswith('Número da Nota'):
            data['Número da Nota'].append(lines[i+1].split()[-1])

        elif lines[i].startswith('Data e Hora de Emissão'):
            data['Data de Emissão'].append(lines[i+1].split()[0])

        elif lines[i].startswith('VALOR TOTAL DA NOTA'):
            data['Valor Total'].append(lines[i].split()[-1])
            
        elif lines[i].startswith('Código do Serviço'):
            data['Código de Serviço'].append(' '.join(lines[i+1].split()[2:15]))

        elif lines[i].startswith('Alíquota'):
            data['Alíquota ISS'].append(lines[89].split()[0])

        elif lines[i].startswith('Valor do ISS'):
            data['Valor ISS'].append(lines[83].split()[0])

        
    # Cria o DataFrame
    df = pd.DataFrame(data)

    # Salva os dados no arquivo Excel
    df.to_excel(output_file, encoding='utf-8', index=False)

    print(f"Arquivo '{output_file}' criado com sucesso!")
Extrair_Modelo_SP('NFS_001283_THINK DIGITAL_2.307,68.pdf', 'dados_extraidos.xlsx')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-0dc3980189df> in <module>
#      65
#      66     print(f"Arquivo '{output_file}' criado com sucesso!")
# ---> 67 Extrair_Modelo_SP('NFS_001283_THINK DIGITAL_2.307,68.pdf', 'dados_extraidos.xlsx')
#
# <ipython-input-28-0dc3980189df> in Extrair_Modelo_SP(pdf_file, output_file)
#      59
#      60     # Cria o DataFrame
# ---> 61     df = pd.DataFrame(data)
#      62
#      63     # Salva os dados no arquivo Excel
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     527
#     528         elif isinstance(data, dict):
# --> 529             mgr = init_dict(data, index, columns, dtype=dtype)
#     530         elif isinstance(data, ma.MaskedArray):
#     531             import numpy.ma.mrecords as mrecords
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\construction.py in init_dict(data, index, columns, dtype)
#     285             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     286         ]
# --> 287     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     288
#     289
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype, verify_integrity)
#      78         # figure out the index, if necessary
#      79         if index is None:
# ---> 80             index = extract_index(arrays)
#      81         else:
#      82             index = ensure_index(index)
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\construction.py in extract_index(data)
#     399             lengths = list(set(raw_lengths))
#     400             if len(lengths) > 1:
# --> 401                 raise ValueError("arrays must all be same length")
#     402
#     403             if have_dicts:
#
# ValueError: arrays must all be same length

# %% [markdown]
# # VER TODO O TEXTO

# %%
import pdfminer.high_level as pdf
import pandas as pd

def Extrair_Modelo_SP(pdf_file, output_file):
    # Extrai o texto do PDF
    text = pdf.extract_text(pdf_file)

    # Exibe as linhas do texto com seus números
    lines = text.split('\n')
    for i, line in enumerate(lines, start=1):
        print(f"Linha {i}: {line}")

    # Resto do seu código...
    # (código para extrair as informações e criar o DataFrame)

Extrair_Modelo_SP('NFS_001283_THINK DIGITAL_2.307,68.pdf', 'dados_extraidos.xlsx')
# Out:
# Linha 1: PREFEITURA DO MUNICÍPIO DE SÃO PAULO
# Linha 2:
# Linha 3: SECRETARIA MUNICIPAL DE FINANÇAS
# Linha 4:
# Linha 5: NOTA FISCAL DE SERVIÇOS ELETRÔNICA - NFS-e
# Linha 6:
# Linha 7: RPS N.001283 Série S7, emitido em 30/03/2022
# Linha 8:
# Linha 9: PRESTADOR DE SERVIÇOS
# Linha 10:
# Linha 11: Número da Nota
# Linha 12: 1283
# Linha 13:
# Linha 14: Data e Hora de Emissão
# Linha 15: 30/03/2022 11:19
# Linha 16:
# Linha 17: Código de Verificação
# Linha 18: QFQI2T8E
# Linha 19:
# Linha 20: C.P.F./C.N.P.J.: 24.614.296/0001-07
# Linha 21: Nome/Razão Social: Think Digital
# Linha 22: Endereço: RUA TAMOIOS, 246 - JARDIM AEROPORTO - 04630-000
# Linha 23: Município: SAO PAULO
# Linha 24:
# Linha 25: UF: SP
# Linha 26:
# Linha 27: Inscrição Municipal: 54591260
# Linha 28:
# Linha 29: TOMADOR DE SERVIÇOS
# Linha 30:
# Linha 31: Nome/Razão Social: BR GAMER LTDA
# Linha 32: C.P.F./C.N.P.J.: 43.874.531/0001-16
# Linha 33: Endereço: AV DOUTORA RUTH CARDOSO, 4777 - JARDIM UNIVERSIDADE PINHEIROS - CEP: 05477-000
# Linha 34: Município: SAO PAULO
# Linha 35:
# Linha 36: E-mail: thiago.soares@brmalls.com.br
# Linha 37:
# Linha 38: UF: SP
# Linha 39:
# Linha 40: Inscrição Municipal:
# Linha 41:
# Linha 42: RMA ONLY 8X5XNBD MERAKI MS225-  REF. AQUISICAO DE GARANTIAS - PROPOSTA BR GAMES - RMA
# Linha 43: MS225 - DOLAR PTAX 4,7486 29/03( Data Vencimento ) 22/06/2022
# Linha 44:
# Linha 45: DISCRIMINAÇÃO DOS SERVIÇOS
# Linha 46:
# Linha 47: VALOR TOTAL DA NOTA = R$       2.307,68
# Linha 48:
# Linha 49: INSS (R$)
# Linha 50:
# Linha 51: IRRF (R$)
# Linha 52:
# Linha 53:           0,00
# Linha 54:
# Linha 55: CSLL (%)
# Linha 56:
# Linha 57: COFINS (R$)
# Linha 58:
# Linha 59: PIS/PASEP (R$)
# Linha 60:
# Linha 61:           0,00
# Linha 62:
# Linha 63:           0,00
# Linha 64:
# Linha 65:           0,00
# Linha 66:
# Linha 67:           0,00
# Linha 68:
# Linha 69: Código do Serviço
# Linha 70: 2800 - Licenciamento Ou Cessao de Direito de Uso de Programas de Computacao, Inclusive Distribuicao
# Linha 71:
# Linha 72: Valor Total das Deduções (R$)
# Linha 73:
# Linha 74: Base de cálculo (R$)
# Linha 75:
# Linha 76: Alíquota (%)
# Linha 77:
# Linha 78: Valor do ISS (R$)
# Linha 79:
# Linha 80: Crédito (R$)
# Linha 81:
# Linha 82:           0,00
# Linha 83:
# Linha 84:          66,92
# Linha 85:
# Linha 86:           0,00
# Linha 87:
# Linha 88:       2.307,68
# Linha 89:
# Linha 90:           2,90
# Linha 91: OUTRAS INFORMAÇÕES
# Linha 92:
# Linha 93: - Esta NFS-e foi emitida com respaldo na Lei n. 14.097/2005.
# Linha 94: - Esta NFS-e não gerou crédito.
# Linha 95: - Esta NFS-e substitui o RPS N.1283 Série S7, emitido em 30/03/2022.
# Linha 96: - Data de vencimento do ISS desta NFS-e: 10/04/2022
# Linha 97: - O valor do ISSQN em destaque é apenas informativo e não deve ser descontado.
# Linha 98:
# Linha 99: 033-7
# Linha 100:
# Linha 101: Comprovante de Entrega
# Linha 102:
# Linha 103: Beneficiário
# Linha 104: THINK DIGITAL
# Linha 105: Pagador
# Linha 106: BR GAMER LTDA
# Linha 107:
# Linha 108: Recebi(emos) o bloqueio/título
# Linha 109: com as características acima.
# Linha 110:
# Linha 111: Data
# Linha 112:
# Linha 113: Agência/Código Beneficiário
# Linha 114: 0118/8283273
# Linha 115: Vencimento
# Linha 116: 22/06/2022
# Linha 117: Data
# Linha 118:
# Linha 119: Nro. Documento
# Linha 120: S7 /001283
# Linha 121: (=)Valor do Documento
# Linha 122:       2.307,68
# Linha 123:
# Linha 124: Assinatura
# Linha 125:
# Linha 126: Entregador
# Linha 127:
# Linha 128: ( )Mudou-se
# Linha 129: ( )Ausente
# Linha 130: ( )Não existe numero
# Linha 131: ( )Recusado
# Linha 132: ( )Não procurado
# Linha 133: ( )Endereço insuficiente
# Linha 134: ( )Desconhecido
# Linha 135: ( )Falecido
# Linha 136: ( )Outros
# Linha 137:
# Linha 138: 033-7
# Linha 139:
# Linha 140: Local Pagamento
# Linha 141: Pagar preferencialmente no banco SANTANDER
# Linha 142: Beneficiário
# Linha 143: THINK DIGITAL
# Linha 144: Data Documento
# Linha 145: 30/03/2022
# Linha 146: Uso do Banco
# Linha 147:
# Linha 148: Nro. Documento
# Linha 149: S7 /001283
# Linha 150: Carteira
# Linha 151:
# Linha 152: 101
# Linha 153:
# Linha 154: Espécie
# Linha 155: R$
# Linha 156:
# Linha 157: Espécie Doc.
# Linha 158: NF
# Linha 159: Quantidade
# Linha 160:
# Linha 161: Aceite
# Linha 162: N
# Linha 163:
# Linha 164: CNPJ Beneficiário
# Linha 165: 24.614.296/0001-07
# Linha 166: Data Processamento
# Linha 167: 14/06/2022
# Linha 168: Valor
# Linha 169:
# Linha 170: Instruções de responsabilidade do beneficiário. Qualquer dúvida sobre este boleto, contate o beneficiário
# Linha 171: Após o vencimento, cobrar : 2% de Multa
# Linha 172: Mora Diaria de R$ 0,77 - equivalente a 1% Pro-Rata
# Linha 173: Sujeito a protesto apos 3 (três) dias do vencimento
# Linha 174: O DEPÓSITO EM CONTA CORRENTE, SE NÃO INFORMADO, NÃO QUITA O DÉBITO!
# Linha 175:
# Linha 176: Recibo do Pagador
# Linha 177:
# Linha 178: Vencimento
# Linha 179:
# Linha 180: Agência/Código Beneficiário
# Linha 181:
# Linha 182: Nosso Número
# Linha 183:
# Linha 184: (=)Valor do Documento
# Linha 185:
# Linha 186: (-)Desconto / Abatimento
# Linha 187:
# Linha 188: (-)Outras Deduções
# Linha 189:
# Linha 190: (+)Mora / Multa
# Linha 191:
# Linha 192: (+)Outros Acréscimos
# Linha 193:
# Linha 194: (=)Valor Cobrado
# Linha 195:
# Linha 196: 22/06/2022
# Linha 197:
# Linha 198: 0118/8283273
# Linha 199:
# Linha 200: 0013616-6
# Linha 201:
# Linha 202:       2.307,68
# Linha 203:
# Linha 204:           0,00
# Linha 205:
# Linha 206:           0,00
# Linha 207:
# Linha 208:           0,00
# Linha 209:
# Linha 210:           0,00
# Linha 211:
# Linha 212:       2.307,68
# Linha 213:
# Linha 214: Pagador / Avalista
# Linha 215:
# Linha 216: 026811 / 01 - BR GAMER LTDA
# Linha 217: AV DOUTORA RUTH CARDOSO, 4777 -  - CEP: 05477-000
# Linha 218: JARDIM UNIVERSIDADE PINHEIROS - SAO PAULO - SP
# Linha 219: C.N.P.J.: 43.874.531/0001-16 - I.E.: 133189042110
# Linha 220:
# Linha 221: 0013616-6
# Linha 222:
# Linha 223: Autenticação Mecânica
# Linha 224:
# Linha 225: 033-7
# Linha 226:
# Linha 227: 03399.82837  27300.000000  13616.601012  2  90240000230768
# Linha 228:
# Linha 229: Local Pagamento
# Linha 230: Pagar preferencialmente no banco SANTANDER
# Linha 231: Beneficiário
# Linha 232: THINK DIGITAL
# Linha 233: Data Documento
# Linha 234: 30/03/2022
# Linha 235: Uso do Banco
# Linha 236:
# Linha 237: Nro. Documento
# Linha 238: S7 /001283
# Linha 239: Carteira
# Linha 240:
# Linha 241: 101
# Linha 242:
# Linha 243: Espécie
# Linha 244: R$
# Linha 245:
# Linha 246: Espécie Doc.
# Linha 247: NF
# Linha 248: Quantidade
# Linha 249:
# Linha 250: Aceite
# Linha 251: N
# Linha 252:
# Linha 253: CNPJ Beneficiário
# Linha 254: 24.614.296/0001-07
# Linha 255: Data Processamento
# Linha 256: 14/06/2022
# Linha 257: Valor
# Linha 258:
# Linha 259: Instruções (Todas informações deste bloqueto são de exclusiva responsabilidade do Beneficiário)
# Linha 260: Após o vencimento, cobrar : 2% de Multa
# Linha 261: Mora Diaria de R$ 0,77 - equivalente a 1% Pro-Rata
# Linha 262: Sujeito a protesto apos 3 (três) dias do vencimento
# Linha 263: O DEPÓSITO EM CONTA CORRENTE, SE NÃO INFORMADO, NÃO QUITA O DÉBITO!
# Linha 264:
# Linha 265: Pagador / Avalista
# Linha 266:
# Linha 267: 026811 / 01 - BR GAMER LTDA
# Linha 268: AV DOUTORA RUTH CARDOSO, 4777 -  - CEP: 05477-000
# Linha 269: JARDIM UNIVERSIDADE PINHEIROS - SAO PAULO - SP
# Linha 270: C.N.P.J.: 43.874.531/0001-16 - I.E.: 133189042110
# Linha 271:
# Linha 272: Vencimento
# Linha 273:
# Linha 274: Agência/Código Beneficiário
# Linha 275:
# Linha 276: Nosso Número
# Linha 277:
# Linha 278: (=)Valor do Documento
# Linha 279:
# Linha 280: (-)Desconto / Abatimento
# Linha 281:
# Linha 282: (-)Outras Deduções
# Linha 283:
# Linha 284: (+)Mora / Multa
# Linha 285:
# Linha 286: (+)Outros Acréscimos
# Linha 287:
# Linha 288: (=)Valor Cobrado
# Linha 289:
# Linha 290: 22/06/2022
# Linha 291:
# Linha 292: 0118/8283273
# Linha 293:
# Linha 294: 0013616-6
# Linha 295:
# Linha 296:       2.307,68
# Linha 297:
# Linha 298:           0,00
# Linha 299:
# Linha 300:           0,00
# Linha 301:
# Linha 302:           0,00
# Linha 303:
# Linha 304:           0,00
# Linha 305:
# Linha 306:       2.307,68
# Linha 307:
# Linha 308: 0013616-6
# Linha 309:
# Linha 310: Autenticação Mecânica - Ficha de Compensação
# Linha 311:
# Linha 312:

# %% [markdown]
# # VER LINHA A LINHA

# %%
import pdfminer.high_level as pdf

# Extrai o texto do PDF
text = pdf.extract_text('NFS_001283_THINK DIGITAL_2.307,68.pdf')

# Extrai as informações do texto
lines = text.split('\n')
for i in range(len(lines)):
    if lines[i].startswith('PRESTADOR DE SERVIÇOS'):
        # Imprime a linha seguinte
        print(lines[i+3])
