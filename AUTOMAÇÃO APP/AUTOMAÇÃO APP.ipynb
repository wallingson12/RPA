# %%
import pyautogui
import pandas as pd                                
df = pd.read_excel("TESTE.xlsx", sheet_name=2)
display(df)
# Out:
#           CNPJCPF Razão Social CódEmpresa       Tributação  DcompPIS  \
# 0  61562112000120          PWC       B503  Lucro Presumido         0
# 1  45997418000153         COCA       B504  Lucro Presumido         0
# 2   4337168000148        HONDA       B505  Lucro Presumido         0
#
#         PIS  DcompCOFINS    COFINS  DcompIRPJ      IRPJ  DcompCSLL      CSLL
# 0  22864.19            0  59373.18          0  148468.6          0  79669.38
# 1  12864.19            0  69373.18          0  748468.6          0  69669.38
# 2  32864.19            0  79373.18          0  848468.6          0  99669.38

# %%
df['PIS A PAGAR'] = df['PIS'] - df['DcompPIS']
df['COFINS A PAGAR'] = df['COFINS'] - df['DcompCOFINS']
df['IRPJ A PAGAR'] = df['IRPJ'] - df['DcompIRPJ']
df['CSLL A PAGAR'] = df['CSLL'] - df['DcompCSLL']

display(df)
# Out:
#           CNPJCPF Razão Social CódEmpresa       Tributação  DcompPIS  \
# 0  61562112000120          PWC       B503  Lucro Presumido         0
# 1  45997418000153         COCA       B504  Lucro Presumido         0
# 2   4337168000148        HONDA       B505  Lucro Presumido         0
#
#         PIS  DcompCOFINS    COFINS  DcompIRPJ      IRPJ  DcompCSLL      CSLL  \
# 0  22864.19            0  59373.18          0  148468.6          0  79669.38
# 1  12864.19            0  69373.18          0  748468.6          0  69669.38
# 2  32864.19            0  79373.18          0  848468.6          0  99669.38
#
#    PIS A PAGAR  COFINS A PAGAR  IRPJ A PAGAR  CSLL A PAGAR
# 0     22864.19        59373.18      148468.6      79669.38
# 1     12864.19        69373.18      748468.6      69669.38
# 2     32864.19        79373.18      848468.6      99669.38

# %%
CNPJ= df['CNPJCPF']
Razao_Social= df['Razão Social']
CódEmpresa_= df['CódEmpresa']
Tributação_= df['Tributação']
PIS_PAGAR = df['PIS A PAGAR']
COFINS_PAGAR = df['COFINS A PAGAR']
IRPJ_PAGAR = df['IRPJ A PAGAR']
CSLL_PAGAR = df['CSLL A PAGAR']

# %%
pyautogui.hotkey('winleft','4')
pyautogui.sleep(4)
pyautogui.press("enter")
pyautogui.press("enter")

for i, CNPJ in enumerate(df["CNPJCPF"]):

    CNPJ = df.loc[i, "CNPJCPF"]
    Razao_Social = df.loc[i, "Razão Social"]
    CódEmpresa_= df.loc[i, 'CódEmpresa']
    Tributação_= df.loc[i, 'Tributação']
    PIS_PAGAR= df.loc[i, 'PIS A PAGAR']
    COFINS_PAGAR = df.loc[i, 'COFINS A PAGAR']
    IRPJ_PAGAR = df.loc[i, 'IRPJ A PAGAR']
    CSLL_PAGAR = df.loc[i, 'CSLL A PAGAR']

    #PIS
    pyautogui.write(str(1708))
    pyautogui.sleep(4)
    pyautogui.press("tab")
    pyautogui.press("m")
    pyautogui.sleep(4)
    pyautogui.press("tab")
    pyautogui.write(str(1221))
    pyautogui.press("tab")
    pyautogui.write(str(PIS_PAGAR))
    pyautogui.sleep(4)
    pyautogui.press("tab")
    pyautogui.sleep(2)
    pyautogui.press("enter")
    pyautogui.press("enter")

    #COFINS
    pyautogui.write(str(1708))
    pyautogui.sleep(4)
    pyautogui.press("tab")
    pyautogui.press("m")
    pyautogui.sleep(4)
    pyautogui.press("tab")
    pyautogui.write(str(1221))
    pyautogui.press("tab")
    pyautogui.write(str(COFINS_PAGAR))
    pyautogui.sleep(4)
    pyautogui.press("tab")
    pyautogui.sleep(2)
    pyautogui.press("enter")
    pyautogui.press("enter")
    
    #IRPJ
    pyautogui.write(str(1708))
    pyautogui.sleep(4)
    pyautogui.press("tab")
    pyautogui.press("m")
    pyautogui.sleep(4)
    pyautogui.press("tab")
    pyautogui.write(str(1221))
    pyautogui.press("tab")
    pyautogui.write(str(IRPJ_PAGAR))
    pyautogui.sleep(4)
    pyautogui.press("tab")
    pyautogui.sleep(2)
    pyautogui.press("enter")
    pyautogui.press("enter")
    
    #CSLL
    pyautogui.write(str(1708))
    pyautogui.sleep(4)
    pyautogui.press("tab")
    pyautogui.press("m")
    pyautogui.sleep(4)
    pyautogui.press("tab")
    pyautogui.write(str(1221))
    pyautogui.press("tab")
    pyautogui.write(str(CSLL_PAGAR))
    pyautogui.sleep(4)
    pyautogui.press("tab")
    pyautogui.sleep(2)
    pyautogui.press("enter")
    pyautogui.press("enter")

    #NOME DA EMPRESA E CNPJ 1
    pyautogui.click("DARE.png")
    pyautogui.write(str(Razao_Social))
    pyautogui.press("tab")
    pyautogui.press("tab")
    pyautogui.sleep(2)
    pyautogui.write(str(CNPJ))
    pyautogui.press("tab")
    pyautogui.press("enter")
    
    pyautogui.click("IMPRIMIR.png")
    pyautogui.sleep(6)
    pyautogui.write(str(Razao_Social))
    pyautogui.write(str(1))
    pyautogui.press("enter")
    pyautogui.sleep(6)
    pyautogui.click("PROXIMO.png")
    
    #2
    pyautogui.press("tab")
    pyautogui.press("tab")
    pyautogui.write(str(CNPJ))
    pyautogui.press("tab")
    pyautogui.press("enter")
    pyautogui.click("IMPRIMIR.png")
    pyautogui.sleep(6)
    pyautogui.write(str(Razao_Social))
    pyautogui.write(str(2))    
    pyautogui.press("enter")
    pyautogui.sleep(6)
    pyautogui.click("PROXIMO.png")
    
    #3
    pyautogui.press("tab")
    pyautogui.press("tab")
    pyautogui.write(str(CNPJ))
    pyautogui.press("tab")
    pyautogui.press("enter")
    pyautogui.click("IMPRIMIR.png")
    pyautogui.sleep(6)
    pyautogui.write(str(Razao_Social))
    pyautogui.write(str(3))    
    pyautogui.press("enter")
    pyautogui.sleep(6)
    pyautogui.click("PROXIMO.png")
    
    #4
    pyautogui.press("tab")
    pyautogui.press("tab")
    pyautogui.write(str(CNPJ))
    pyautogui.press("tab")
    pyautogui.press("enter")
    pyautogui.click("IMPRIMIR.png")
    pyautogui.sleep(6)
    pyautogui.write(str(Razao_Social))
    pyautogui.write(str(4))   
    pyautogui.press("enter")
    pyautogui.sleep(6)
    pyautogui.click("CANCELAR.png")
    pyautogui.moveTo(x=56, y=214)
    pyautogui.click(x=56, y=214)
    
pyautogui.alert('PARABÉNS SEU PROJETO FOI UM SUCESSO')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-9fc251e81f11> in <module>
#      89     pyautogui.press("enter")
#      90
# ---> 91     pyautogui.click("IMPRIMIR.png")
#      92     pyautogui.sleep(6)
#      93     pyautogui.write(str(Razao_Social))
#
# ~\Anaconda3\lib\site-packages\pyautogui\__init__.py in wrapper(*args, **kwargs)
#     596     def wrapper(*args, **kwargs):
#     597         failSafeCheck()
# --> 598         returnVal = wrappedFunction(*args, **kwargs)
#     599         _handlePause(kwargs.get("_pause", True))
#     600         return returnVal
#
# ~\Anaconda3\lib\site-packages\pyautogui\__init__.py in click(x, y, clicks, interval, button, duration, tween, logScreenshot, _pause)
#     978     # TODO: I'm leaving buttons 4, 5, 6, and 7 undocumented for now. I need to understand how they work.
#     979     button = _normalizeButton(button)
# ...
